# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
covid_data=pd.read_csv('https://data.chhs.ca.gov/dataset/e39edc8e-9db1-40a7-9e87-89169401c3f5/resource/de27ce58-edc8-45fb-bebc-08c4b29c5efe/download/covid19postvaxstatewidestats_07172022.csv%27')
covid_data = covid_data.set_index('date')
covid_data.head(533)
# Out:
#                   area area_type  unvaccinated_cases  vaccinated_cases  \
# date
# 2021-02-01  California     State               13867                24
# 2021-02-02  California     State               11388                18
# 2021-02-03  California     State               10360                27
# 2021-02-04  California     State                9030                18
# 2021-02-05  California     State                8429                15
# ...                ...       ...                 ...               ...
# 2022-07-13  California     State               10167              2468
# 2022-07-14  California     State                9708              2260
# 2022-07-15  California     State                8804              2243
# 2022-07-16  California     State                5924              1498
# 2022-07-17  California     State                4885              1311
#
#             boosted_cases  unvaccinated_hosp  vaccinated_hosp  boosted_hosp  \
# date
# 2021-02-01              0                773                1             0
# 2021-02-02              0                600                0             0
# 2021-02-03              0                548                0             0
# 2021-02-04              0                484                0             0
# 2021-02-05              0                500                0             0
# ...                   ...                ...              ...           ...
# 2022-07-13           5958                217               44            80
# 2022-07-14           5377                210               39            73
# 2022-07-15           5099                195               31            57
# 2022-07-16           3645                155               29            56
# 2022-07-17           3212                121               25            38
#
#             unvaccinated_deaths  vaccinated_deaths  ...  population_boosted  \
# date                                                ...
# 2021-02-01                   12                  0  ...                   0
# 2021-02-02                   15                  0  ...                   0
# 2021-02-03                   18                  0  ...                   0
# 2021-02-04                   19                  0  ...                   0
# 2021-02-05                   28                  0  ...                   0
# ...                         ...                ...  ...                 ...
# 2022-07-13                   17                  3  ...            15990885
# 2022-07-14                   10                  3  ...            15998929
# 2022-07-15                   15                  1  ...            16007721
# 2022-07-16                   12                  4  ...            16011638
# 2022-07-17                   20                  2  ...            16013870
#
#             unvaccinated_cases_per_100k  vaccinated_cases_per_100k  \
# date
# 2021-02-01                          NaN                        NaN
# 2021-02-02                          NaN                        NaN
# 2021-02-03                          NaN                        NaN
# 2021-02-04                          NaN                        NaN
# 2021-02-05                          NaN                        NaN
# ...                                 ...                        ...
# 2022-07-13                   228.649954                  19.829962
# 2022-07-14                   228.036507                  19.424501
# 2022-07-15                   225.238068                  19.256849
# 2022-07-16                   224.302763                  19.167729
# 2022-07-17                   222.128751                  19.171574
#
#             boosted_cases_per_100k  unvaccinated_hosp_per_100k  \
# date
# 2021-02-01                     NaN                         NaN
# 2021-02-02                     NaN                         NaN
# 2021-02-03                     NaN                         NaN
# 2021-02-04                     NaN                         NaN
# 2021-02-05                     NaN                         NaN
# ...                            ...                         ...
# 2022-07-13               33.523562                    5.429738
# 2022-07-14               32.799517                    5.458667
# 2022-07-15               32.282636                    5.350407
# 2022-07-16               32.039195                    5.169581
# 2022-07-17               31.992802                    4.875138
#
#             vaccinated_hosp_per_100k  boosted_hosp_per_100k  \
# date
# 2021-02-01                       NaN                    NaN
# 2021-02-02                       NaN                    NaN
# 2021-02-03                       NaN                    NaN
# 2021-02-04                       NaN                    NaN
# 2021-02-05                       NaN                    NaN
# ...                              ...                    ...
# 2022-07-13                  0.432764               0.578901
# 2022-07-14                  0.421584               0.536643
# 2022-07-15                  0.393953               0.501544
# 2022-07-16                  0.362372               0.450565
# 2022-07-17                  0.344680               0.418387
#
#             unvaccinated_deaths_per_100k  vaccinated_deaths_per_100k  \
# date
# 2021-02-01                           NaN                         NaN
# 2021-02-02                           NaN                         NaN
# 2021-02-03                           NaN                         NaN
# 2021-02-04                           NaN                         NaN
# 2021-02-05                           NaN                         NaN
# ...                                  ...                         ...
# 2022-07-13                      0.453357                    0.041758
# 2022-07-14                      0.446682                    0.037981
# 2022-07-15                      0.408321                    0.027868
# 2022-07-16                      0.366237                    0.027875
# 2022-07-17                      0.373385                    0.024077
#
#             boosted_deaths_per_100k
# date
# 2021-02-01                      NaN
# 2021-02-02                      NaN
# 2021-02-03                      NaN
# 2021-02-04                      NaN
# 2021-02-05                      NaN
# ...                             ...
# 2022-07-13                 0.030374
# 2022-07-14                 0.031252
# 2022-07-15                 0.031235
# 2022-07-16                 0.029443
# 2022-07-17                 0.026763
#
# [532 rows x 23 columns]

# %%
unv_cases = 'unvaccinated_cases'
v_cases = 'vaccinated_cases'
print(covid_data[unv_cases])
print(covid_data[v_cases])
# Out:
# date
# 2021-02-01    13867
# 2021-02-02    11388
# 2021-02-03    10360
# 2021-02-04     9030
# 2021-02-05     8429
#               ...
# 2022-07-13    10167
# 2022-07-14     9708
# 2022-07-15     8804
# 2022-07-16     5924
# 2022-07-17     4885
# Name: unvaccinated_cases, Length: 532, dtype: int64
# date
# 2021-02-01      24
# 2021-02-02      18
# 2021-02-03      27
# 2021-02-04      18
# 2021-02-05      15
#               ...
# 2022-07-13    2468
# 2022-07-14    2260
# 2022-07-15    2243
# 2022-07-16    1498
# 2022-07-17    1311
# Name: vaccinated_cases, Length: 532, dtype: int64

# %%
def stats(column):
    '''This function obtains the statistics for a specific column(s) that you ask for'''
    stats_df = covid_data.describe()
    return_column = stats_df.loc[:,column]
    print('Stats for ' + column)
    return return_column

stats(unv_cases)
# Out:
# Stats for unvaccinated_cases
# count      532.000000
# mean      5299.975564
# std       7506.750534
# min        383.000000
# 25%       1621.000000
# 50%       3136.500000
# 75%       5946.250000
# max      52980.000000
# Name: unvaccinated_cases, dtype: float64
